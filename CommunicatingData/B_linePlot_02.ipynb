# %%
import pandas as pd
#import matplotlib.pyplot as plt
#import pylab as pl
#import numpy as np
# %matplotlib inline

# %% [markdown]
# # Example
#
# 1. An object with position $y = \frac{1}{2}at^2,$ and $v = at.$ In our example the dimensional analysis for the the acceleration is $[a]= \frac{[L]}{[T][T]}$

# %%
df = pd.DataFrame({

   'position': [1*0.5, 4*0.5, 9*0.5, 16*0.5, 25*0.5],

   'velocity': [1, 2, 3, 4, 5]

   }, index=[1, 2, 3, 4, 5])

lines = df.plot.line()

# %%
axes = df.plot.line(subplots=True)

#type(axes)

# %% [markdown]
# # References1
# [1] Ozdemir, Sinan. Principles of data Science. Packt. 2016. ISBN 978-1-78588-791-8
#
# [2] Pandas https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html
